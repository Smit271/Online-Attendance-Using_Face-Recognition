# %%
# USAGE
# python detect_faces.py --image rooster.jpg --prototxt deploy.prototxt.txt --model res10_300x300_ssd_iter_140000.caffemodel

# import the necessary packagesa
import numpy as np
import argparse
import cv2
import time
import matplotlib.pyplot as plt
import os
from numpy import asarray
from PIL import Image
from numpy import savez_compressed
from numpy import load
from numpy import expand_dims
from keras.models import load_model
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import psutil

# %config Completer.use_jedi = False
confidence_threshold  = 0.9
required_size = (160,160)


facenet_model = load_model('facenet_keras.h5')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/kinetic/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/kinetic/anaconda3/envs/tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# /home/kinetic/anaconda3/envs/tf1/lib/python3.6/site-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
import shutil
filepath = "./8-Dataset/"

# %%
#rename files
train_path = filepath+"train/"
for name in os.listdir(train_path):
    for ind,filename in enumerate(os.listdir(train_path+name)):
            dst = train_path +name+ "/"+name+"_train_"+str(ind)
            src = train_path+name + "/"+filename
            os.rename(src,dst)
            print(filename)
# Out:
# Screenshot at 2021-03-23 15-01-07.png
# Screenshot at 2021-03-23 15-04-53.png
# IMG-20201016-WA0017.jpg
# Screenshot at 2021-03-23 15-06-10.png
# IMG-20200803-WA0091.jpg
# Screenshot at 2021-03-23 15-06-34.png
# IMG-20210322-WA0003.jpg
# Screenshot at 2021-03-23 15-04-27.png
# Screenshot at 2021-03-23 15-00-19.png
# IMG20201116081625_00.jpg
# Screenshot at 2021-03-23 15-00-32.png
# Screenshot at 2021-03-23 15-05-21.png
# Screenshot at 2021-03-23 15-01-33.png
# Screenshot at 2021-03-23 15-04-08.png
# IMG_5927.jpg
# IMG_7781.HEIC
# Screenshot at 2021-03-23 15-03-39.png
# Screenshot at 2021-03-23 15-03-08.png
# Screenshot at 2021-03-23 14-59-50.png
# Screenshot at 2021-03-23 15-00-52.png
# IMG-20200803-WA0087.jpg
# Screenshot at 2021-03-23 15-02-44.png
# IMG20210320100029_00.jpg
# Screenshot at 2021-03-23 15-05-44.png
# IMG-20210322-WA0002.jpg
# IMG_20201116_193942_745.jpg
# DSC_0043.jpg
# SAVE_20201102_200247.jpg
# IMG_20200113_000340.jpg
# 20200921_031427_0.jpg
# DSC_0081.jpg
# 20200514_105242_0.jpg
# DSC_0121.jpg
# InShot_20200629_143908046.jpg
# IMG-20200225-WA0009.jpg
# 30.10.2020 18.26.22 881 1170626490.jpg
# IMG_20200113_000359.jpg
# IMG_5925.jpg
# InShot_20201102_213314750.jpg
# 847A8505-D66E-4BA3-BD1C-300BA6A87038L0001.jpg
# IMG_20201116_191721_013.jpg
# IMG-20210114-WA0011.jpg
# IMG_20200218_174715.jpg
# B2A42328-B72B-41E4-87B8-37BAC5DC2531L0001.jpg
# 30.10.2020 18.47.29 898 1761200262.jpg
# IMG_5926.jpg
# IMG_20200113_000546_752.jpg
# Screenshot at 2021-03-23 23-41-15.png
# IMG_7926.JPG
# IMG_9084_Original.HEIC
# Screenshot at 2021-03-23 23-40-36.png
# IMG_7904.JPG
# Screenshot at 2021-03-23 23-41-01.png
# unnamed.jpg
# fc023ec3-1b38-4de8-a327-806e94325e55_Original.jpg
# IMG_0937_Original.HEIC
# Screenshot at 2021-03-23 15-18-55.png
# Screenshot at 2021-03-23 15-20-16.png
# IMG_20200610_094236.jpg
# IMG_20201128_141924.jpg
# Screenshot at 2021-03-23 15-18-35.png
# IMG_20191007_203955.jpg
# IMG-20200217-WA0068.jpg
# IMG_20191206_080234.jpg
# IMG_20210114_182016.jpg
# AB2563A3-20F5-4079-84D7-4F9C2B673C36L0001.jpeg
# Screenshot at 2021-03-23 15-22-26.png
# IMG_20190905_191710.jpg
# Screenshot at 2021-03-23 15-18-11.png
# IMG_20200429_100307.jpg
# Screenshot at 2021-03-23 15-17-16.png
# IMG_20200602_123721.jpg
# Screenshot at 2021-03-23 15-19-37.png
# Screenshot at 2021-03-23 15-19-59.png
# Screenshot at 2021-03-23 15-21-23.png
# Screenshot at 2021-03-23 23-36-25.png
# IMG_20190626_222942.jpg
# PicsArt_11-09-10.20.50.jpg
# IMG_20190208_153213.jpg
# Screenshot at 2021-03-23 23-36-50.png
# IMG_20200323_232222.jpg
# PicsArt_12-28-10.01.10.jpg
# IMG_20180930_081230.jpg
# Screenshot at 2021-03-23 23-38-17.png
# Snapchat-830265045.jpg
# IMG_20191222_145116_697.jpg
# Screenshot at 2021-03-23 23-37-21.png
# 2017-08-21-04-04-30-522-1.jpg
# PicsArt_06-12-01.34.05.jpg
# IMG_20170813_154228_110.jpg
# Screenshot at 2021-03-23 23-37-52.png
# Snapchat-649928866.jpg
# PicsArt_07-04-06.08.14.jpg
# IMG_20191021_235310_972.jpg
# 2019-07-21-14-02-22-886.jpg
# IMG_20191008_124924_405.jpg
# Screenshot at 2021-03-23 23-35-39.png
# IMG_20200420_135004_330.jpg
# IMG_20190919_155055_597.jpg
# 2018-11-08-13-34-00-797.jpg

# %% [markdown]
# ### Order Train-Test data from given directory

# %%
#make train-test data
from pathlib import Path
src_path = "8_photos"
dest_path = "8-Dataset"
#make root directory
Path(dest_path).mkdir(parents=True, exist_ok=True)
#make train & test in root
Path(dest_path+"/train").mkdir(parents=True, exist_ok=True)
Path(dest_path+"/test").mkdir(parents=True, exist_ok=True)
class_labels = os.listdir(src_path)
types = ["train","test"]

for label in class_labels:
    #define paths
    label_dest_path_train = dest_path+"/train/"+label
    label_dest_path_test = dest_path+"/test/"+label
    label_src_path = src_path+"/"+label
    #make label directory in train & test
    Path(label_dest_path_train).mkdir(parents=True, exist_ok=True)
    Path(label_dest_path_test).mkdir(parents=True, exist_ok=True)
    #list out all photos from source directory
    photos = os.listdir(label_src_path)
    #train test split
    train,test = train_test_split(photos,test_size=0.15,random_state=1)
    
    #delete existing files
    for f in os.listdir(label_dest_path_train):
        os.remove(os.path.join(label_dest_path_train, f)) 
    #delte existing files
    for f in os.listdir(label_dest_path_test):
        os.remove(os.path.join(label_dest_path_test, f))
    
    for each in train:
        
        shutil.copy(label_src_path+"/"+each,label_dest_path_train)
    
    for each in test:
       
        shutil.copy(label_src_path+"/"+each,label_dest_path_test)
    
    
    
    print(label,len(train),len(test))
# Out:
# Smit 25 5
# Malav 22 5
# Lance 22 5
# Nency 17 3
# Mahisha 25 5
# Rutvik 31 6
# Karm 25 5
# Isha 25 5

# %%
#load pretrained model of dnn(deep neural network)
def load_face_det_model():
    print("[INFO] loading model...")
    model = cv2.dnn.readNetFromCaffe("deploy.prototxt.txt", "res10_300x300_ssd_iter_140000.caffemodel")
    if model:
        print("model loaded")
        return model

def close_all_window():
    for proc in psutil.process_iter():
        if proc.name() == "display":
            proc.kill()

# %%
#load image in numpy array
def extract_faces(model,filepath,required_size=(160,160)):
    cropped = []
    original = []
    files = os.listdir(filepath)
    for filename in files:
        #open image & convert into an numpy array
        image = cv2.imread(filepath+"/"+filename)
        im = Image.open(filepath+"/"+filename)
        image = np.array(im)
        
        #print("++++ {} ++++".format(filename))
        #print("original image shape=",image.shape)
        
        #resize the image
        image = cv2.resize(image, (300,300))
   
        #image preprocessing like mean substraction
        blob = cv2.dnn.blobFromImage(image, 1.0,(300, 300), (104.0, 177.0, 123.0))
        #print(blob.shape)

        # pass the blob through the network and obtain the detections and
        # predictions
        model.setInput(blob)
        try:
            detections = model.forward()
        except:
            print("skip {} due to model error".format(filename))
            continue
        #print(detections.shape)
        '''
        detection.shape =  (1, 1, 200, 7)
        7 columns:

        3rd column = confidence of pixel
        4th column = (startX)/width
        5th column = (startY)/height
        6th column = (endX)/width
        7th column = (endY)/height

        '''
       
        height, width = image.shape[:2]
        #print("resized image shape:",image.shape)
        #Image.fromarray(image, 'RGB').show()
        
        #maximum of all detections -> detect most accurate one face
        confidence = detections.max(axis=2)[0][0][2]
        arg = detections.argmax(axis=2)[0][0][2]
        #print(arg)
        #take last axis
        each = detections[0][0][arg]
        #print("Maximum confidence:",confidence)
    #multiple image detection
    #     for each in detections[0][0]:
    #         confidence = each[2]
        if confidence >0.5:
            try:
                #print(confidence)
                startX_factor, startY_factor, endX_factor, endY_factor = each[3:]
                #print(startX_factor)
                startX, startY, endX, endY = int(startX_factor*width), int(startY_factor*height), int(endX_factor*width), int(endY_factor*height)
                #print((startX, startY, endX, endY))
                #cv2.rectangle(image,(startX,startY),(endX,endY),(0,255,0),2)
                #text = str(round(confidence*100,2))
                #cv2.putText(image,text,(startX,startY-10),cv2.FONT_HERSHEY_SIMPLEX,0.45,(0,255,0),2)
                crop = image[startY:endY,startX:endX]
                #Image.fromarray(image,'RGB').show()
                #Image.fromarray(crop, 'RGB').show()

                #resize face to (160,160,3)
                crop_img = Image.fromarray(crop)
                crop_img = crop_img.resize(required_size)
                face = asarray(crop_img)
                #print("face shape",face.shape)
                if confidence<0.5:
                    Image.fromarray(face, 'RGB').show()
               
                cropped.append(face)
                original.append(image)
            except:
                print("face not detected in",filename)
        else:
            print("low confidence:{},face not detected in {}".format(confidence,filename))
    print("{}/{} faces detected in {}".format(len(cropped),len(files),filepath))
    return (original,cropped)
      
#load image in numpy array
def extract_face_single_image(model,image_path,required_size=(160,160)):

    #open image & convert into an numpy array
    image = cv2.imread(image_path)
    im = Image.open(image_path)
    image = np.array(im)

    #resize the image
    image = cv2.resize(image, (300,300))

    #image preprocessing like mean substraction
    blob = cv2.dnn.blobFromImage(image, 1.0,(300, 300), (104.0, 177.0, 123.0))
    #print(blob.shape)

    # pass the blob through the network and obtain the detections and
    # predictions
    model.setInput(blob)
    detections = model.forward()
    #print(detections.shape)
    '''
    detection.shape =  (1, 1, 200, 7)
    7 columns:

    3rd column = confidence of pixel
    4th column = (startX)/width
    5th column = (startY)/height
    6th column = (endX)/width
    7th column = (endY)/height

    '''

    height, width = image.shape[:2]
    #print("resized image shape:",image.shape)
    #Image.fromarray(image, 'RGB').show()

    #maximum of all detections -> detect most accurate one face
    confidence = detections.max(axis=2)[0][0][2]
    arg = detections.argmax(axis=2)[0][0][2]
    #print(arg)
    #take last axis
    each = detections[0][0][arg]
    #print("Maximum confidence:",confidence)
#multiple image detection
#     for each in detections[0][0]:
#         confidence = each[2]
    if confidence >0.1:
        #print(confidence)
        startX_factor, startY_factor, endX_factor, endY_factor = each[3:]
        #print(startX_factor)
        startX, startY, endX, endY = int(startX_factor*width), int(startY_factor*height), int(endX_factor*width), int(endY_factor*height)
        print((startX, startY, endX, endY))
        #cv2.rectangle(image,(startX,startY),(endX,endY),(0,255,0),2)
        #text = str(round(confidence*100,2))
        #cv2.putText(image,text,(startX,startY-10),cv2.FONT_HERSHEY_SIMPLEX,0.45,(0,255,0),2)
        crop = image[startY:endY,startX:endX]
        #Image.fromarray(image,'RGB').show()
        Image.fromarray(crop, 'RGB').show()

        #resize face to (160,160,3)
        crop_img = Image.fromarray(crop)
        crop_img = crop_img.resize(required_size)
        face = asarray(crop_img)
        #print("face shape",face.shape)
        
    return (image,face)

# %%
model = load_face_det_model()
X_faces_train, Y_faces_train = list(), list()
X_original_train, X_original_test = list(), list()
train_path = filepath+"train/"
for name in os.listdir(train_path):
    o,c = extract_faces(model,train_path+name)
    X_faces_train.extend(c)
    X_original_train.extend(o)
    Y_faces_train.extend([name for i in range(len(c))])
    
X_faces_test, Y_faces_test = list(), list()
test_path = filepath+"test/"
for name in os.listdir(test_path):
    o,c = extract_faces(model,test_path+name)
    X_faces_test.extend(c)
    X_original_test.extend(o)
    Y_faces_test.extend([name for i in range(len(c))])

#save compressed file of faces       
savez_compressed("8-faces.npz",asarray(X_faces_train),asarray(Y_faces_train),asarray(X_faces_test),asarray(Y_faces_test))
savez_compressed("8-data.npz",asarray(X_original_train),asarray(Y_faces_train),asarray(X_original_test),asarray(Y_faces_test))
# Out:
# [INFO] loading model...
# model loaded
# 25/25 faces detected in ./8-Dataset/train/Smit
# 22/22 faces detected in ./8-Dataset/train/Malav
# 22/22 faces detected in ./8-Dataset/train/Lance
# 17/17 faces detected in ./8-Dataset/train/Nency
# face not detected in Mahisha_train_11
# face not detected in Mahisha_train_6
# face not detected in Mahisha_train_22
# 22/25 faces detected in ./8-Dataset/train/Mahisha
# low confidence:0.12448728829622269,face not detected in Rutvik_train_16
# 30/31 faces detected in ./8-Dataset/train/Rutvik
# 25/25 faces detected in ./8-Dataset/train/Karm
# face not detected in Isha_train_6
# low confidence:0.1431455910205841,face not detected in Isha_train_7
# low confidence:0.13256528973579407,face not detected in Isha_train_3
# face not detected in Isha_train_17
# 21/25 faces detected in ./8-Dataset/train/Isha
# 5/5 faces detected in ./8-Dataset/test/Smit
# low confidence:0.14227016270160675,face not detected in Malav_test_1
# 4/5 faces detected in ./8-Dataset/test/Malav
# 5/5 faces detected in ./8-Dataset/test/Lance
# low confidence:0.35396844148635864,face not detected in Nency_test_2
# 2/3 faces detected in ./8-Dataset/test/Nency
# 5/5 faces detected in ./8-Dataset/test/Mahisha
# low confidence:0.2423924058675766,face not detected in Rutvik_test_4
# 5/6 faces detected in ./8-Dataset/test/Rutvik
# 5/5 faces detected in ./8-Dataset/test/Karm
# skip Isha_test_0 due to model error
# 4/5 faces detected in ./8-Dataset/test/Isha

# %% [markdown]
# ### get m*128 embeddings

# %%
def get_embeddings(model,face_pixels):
    face_pixels = face_pixels.astype('float32')
    #Z-score
    mean = face_pixels.mean()
    std = face_pixels.std()
    face_pixels = (face_pixels-mean)/std 
    
    #convert in required dimension for facenet model
    #print("before:",face_pixels.shape)
    samples = expand_dims(face_pixels,axis=0)
    #print("after:",samples.shape)
    embs = model.predict(samples)
    print(embs[0].shape)
    #print(embs[0])
    return embs[0]

# %%
data = load("8-faces.npz")
X_faces_train,Y_faces_train,X_faces_test,Y_faces_test = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']


X_embs_train, X_embs_test = list(),list()
for face in X_faces_train:
    embeddings = get_embeddings(facenet_model,face)
    X_embs_train.append(embeddings)

for face in X_faces_test:
    embeddings = get_embeddings(facenet_model,face)
    X_embs_test.append(embeddings)
    
savez_compressed("8-face-embeddings.npz",asarray(X_embs_train),Y_faces_train,asarray(X_embs_test),Y_faces_test)

# %% [markdown]
# ### Make a Classifier for Comparing Embeddings

# %%
# load dataset
def load_face_classifier():
    data = load('8-face-embeddings.npz')
    trainX, trainy, testX, testy = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']
    print('Dataset: train=%d, test=%d' % (trainX.shape[0], testX.shape[0]))

    #l-2 normalization
    encoder = Normalizer()
    trainX = encoder.transform(trainX)
    testX = encoder.transform(testX)
    testX.shape
   
    #conver string labels into numeric
    label_encoder = LabelEncoder()
    label_encoder.fit(trainy)
    trainy = label_encoder.transform(trainy)
    testy = label_encoder.transform(testy)

    #load SVM Classifier
    svm_model = SVC(kernel='linear',probability=True)
    svm_model.fit(trainX,trainy)

    #prediction
    train_pred = svm_model.predict(trainX)
    test_pred = svm_model.predict(testX)

    #accuracy score
    print("train accuracy:",accuracy_score(trainy,train_pred))
    print("test accuracy:",accuracy_score(testy,test_pred))
    return (svm_model,label_encoder)

def load_face_classifier_with_labels():
    data = load('8-face-embeddings.npz')
    trainX, trainy, testX, testy = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']
    print('Dataset: train=%d, test=%d' % (trainX.shape[0], testX.shape[0]))

    #l-2 normalization
    encoder = Normalizer()
    trainX = encoder.transform(trainX)
    testX = encoder.transform(testX)
    testX.shape
   
    #conver string labels into numeric
    label_encoder = LabelEncoder()
    label_encoder.fit(trainy)
    trainy = label_encoder.transform(trainy)
    testy = label_encoder.transform(testy)

    #load SVM Classifier
    svm_model = SVC(kernel='linear',probability=True)
    svm_model.fit(trainX,trainy)

    #prediction
    train_pred = svm_model.predict(trainX)
    test_pred = svm_model.predict(testX)
    
    labels = label_encoder.inverse_transform(testy)
    #accuracy score
    print("train accuracy:",accuracy_score(trainy,train_pred))
    print("test accuracy:",accuracy_score(testy,test_pred))
    return (svm_model,label_encoder,labels)

# %% [markdown]
# ### Visualizing Face-prints or embeddings

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd

data = load('8-face-embeddings.npz')
trainX, trainy, testX, testy = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']

encoder = Normalizer()
trainX = encoder.transform(trainX)
#trainX = StandardScaler().fit_transform(trainX)
pca = PCA(n_components=2)

principle_comp = pca.fit_transform(trainX)
df = pd.DataFrame(principle_comp)
df[2] = trainy
labels = list(set(testy))
colors = ["red","blue","black","yellow","orange","green","purple","gray"]

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)
ax.set_title("FACE-PRINTS of people")
ax.set_xlabel("PCA1")
ax.set_ylabel("PCA2")
for label,color in zip(labels,colors):
    ax.scatter(df[df[2] == label][0],df[df[2] == label][1],c=color)
ax.grid()
ax.legend(labels)

# %% [markdown]
# ### Testing Images from test directories

# %%
data = load("8-data.npz")
X, Y, x, y = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']
data = load('8-face-embeddings.npz')
trainX, trainy, testX, testy = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']
#print(testy)
#convert numeric to string labels
svm_model, label_encoder,labels = load_face_classifier_with_labels()

#labels = label_encoder.inverse_transform(testy)

#find probabilites of all test cases
probs = svm_model.predict_proba(testX)

#choose random number
selection = np.random.randint(0,len(testy))
#expand it's dimenstion
singleX = expand_dims(testX[selection],axis=0)
#predict class
clas = svm_model.predict(singleX)
predicted = label_encoder.inverse_transform(list(clas))[0]
pred_prob = max(probs[selection])
print("svm_model output : This is Face of '{}' with proobability = {}".format(predicted,pred_prob))
print("Expected : ",labels[selection])
Image.fromarray(x[selection])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-69d16476b6e6> in <module>
#       5 #print(testy)
#       6 #convert numeric to string labels
# ----> 7 svm_model, label_encoder,labels = load_face_classifier_with_labels()
#       8
#       9 #labels = label_encoder.inverse_transform(testy)
#
# NameError: name 'load_face_classifier_with_labels' is not defined

# %%
'''
1)take input image
2)extract face from it
3)find embeddings of face
4)predict this embedding
'''
(svm_model,label_encoder) = load_face_classifier()
encoder = Normalizer()

def test_your_own_image(image_path):
    dnn_model = load_face_det_model()
    image,face_pixel = extract_face_single_image(dnn_model,image_path)
    embs = get_embeddings(facenet_model,face_pixel)
    encoder = Normalizer()
    embs = encoder.transform(expand_dims(embs,axis=0))
    pred = svm_model.predict(embs)
    print(svm_model.predict_proba(embs))
    prob = max(svm_model.predict_proba(embs)[0])
    print(prob.shape)
    print("this is image of '{}' with probability={}".format(label_encoder.inverse_transform(pred)[0],prob))
    Image.fromarray(image).show()
    print(pred)
    svm_model.

test_your_own_image("/media/kinetic/New Volume/all photos/NOTE 5/Aabu/DSCN0894.JPG")
# Out:
# Dataset: train=56, test=11
# train accuracy: 1.0
# test accuracy: 1.0
# [INFO] loading model...
# model loaded
# (55, 46, 82, 83)
# (128,)
# [[0.16206596 0.09535445 0.74257959]]
# ()
# this is image of 'rutvik' with probability=0.7425795929475377
# [2]

# %%
close_all_window()

# %%
import pickle 
svm,label_en = load_face_classifier()
# Save the trained model as a pickle string. 
saved_model = pickle.dump(svm, open("svm_model", 'wb'))
# Out:
# Dataset: train=56, test=11
# train accuracy: 1.0
# test accuracy: 1.0

# %%
mod = pickle.dump(label_en,open("label_encoder",'wb'))

# %%
label_encoder = pickle.load(open("label_encoder","rb"))
str(label_encoder.inverse_transform([1])[0])
# Out:
# 'lance'

# %%
data = load('8-data.npz')
trainX, trainy, testX, testy = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']

# %%
img = testX[4]

# %%
flip_img = []
for channel in range(3):
    temp = []
    for each in img[:,:,channel]:
        temp.append(each[::-1])
    flip_img.append(temp)

# %%
new = []
for i in range(300):
    temp = []
    for j in range(300):
        print(i,j)
        print(flip_img[:3][i][j])
        temp.append(flip_img[:3][i][j])
    new.append(temp)
# Out:
# 0 0
# [118 118 118 118 118 118 118 118 118 118 118 118 118 118 118 118 118 118
#  118 118 116 116 116 116 116 116 116 116 116 116 116 116 116 117 117 117
#  117 117 117 117 116 116 116 116 116 116 116 116 116 116 115 115 115 115
#  115 115 115 115 115 115 115 115 115 115 115 115 115 115 115 115 114 114
#  114 114 114 114 114 114 114 114 114 114 114 114 114 114 114 114 114 114
#  113 113 112 112 112 113 113 113 113 113 115 115 115 115 115 115 115 115
#  115 115 114 114 114 114 114 113 113 113 113 113 114 114 114 114 114 113
#  113 113 113 113 113 113 113 113 113 113 113 113 113 113 112 112 112 111
#  110 111 111 111 111 111 110 110 110 111 111 110 110 110 110 110 110 110
#  110 110 110 109 109 109 109 109 109 109 108 108 108 109 109 108 108 108
#  108 108 108 108 108 108 108 108 108 108 108 108 108 108 108 108 108 108
#  108 108 108 108 107 107 107 107 107 107 107 107 107 107 106 106 106 106
#  106 106 107 107 107 107 107 107 107 107 107 107 108 108 107 107 107 108
#  108 108 108 108 108 108 108 108 108 109 109 110 110 110 110 110 110 111
#  112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  113 113 113 113 113 113 113 113 113 113 114 114 114 114 114 116 116 116
#  116 116 116 116 116 116 116 114 114 114 114 114]
# 0 1
# [118 118 118 118 118 118 118 118 118 118 118 118 118 118 118 118 118 118
#  118 118 116 116 116 116 116 116 116 116 116 116 116 116 116 117 117 117
#  117 117 117 117 116 116 116 116 116 116 116 116 116 116 115 115 115 115
#  115 116 116 115 115 115 115 115 115 115 115 115 115 115 115 115 114 114
#  114 114 114 114 114 114 114 114 114 114 114 114 114 114 114 114 114 114
#  113 113 113 114 114 113 113 113 113 113 115 115 115 115 115 115 115 115
#  115 115 114 114 114 114 114 113 113 113 113 113 114 114 114 114 114 113
#  113 113 113 113 113 113 113 113 113 113 113 113 113 113 112 112 112 111
#  110 111 111 111 111 111 110 110 110 111 111 110 110 110 110 110 110 110
